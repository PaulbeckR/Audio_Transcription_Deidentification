# %% [markdown]
# Pretraining Whisper:
#
# learnopencv.com/fine-tuning-whisper-on-custom-dataset/

# %%
# from transformers import (
#     WhisperTokenizer,
#     WhisperProcessor, 
#     WhisperForConditionalGeneration,
#     Seq2SeqTrainingArguments,
#     Seq2SeqTrainer
# )

# from datasets import load_dataset
# import torch
# import evaluate

# model_id = 'openai/whisper-small'
# out_dir = 'whisper_small_atco2'
# epocs = 10
batch_size = 32
